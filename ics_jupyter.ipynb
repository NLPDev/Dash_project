# %%
from icalendar import Calendar

# %%
g = open('calendar.ics','rb')

# %%
gcal = Calendar.from_ical(g.read())

# %%
result_list = []

# %%
for event in gcal.walk('vevent'):
    each_val = {}
    if event.get('name'):
        each_val['name'] = event.get('name')

    each_val['start'] = event.get('dtstart').dt

    if event.get('dtend'):
        each_val['end'] = event.get('dtend').dt

    if event.get('dtend'):
        duration = each_val['end'] - each_val['start']
        each_val['duration'] = duration.seconds

    if event.get('status'):
        each_val['status'] = event.get('status')

    if event.get('description'):
        each_val['description'] = event.get('description')

    if event.get('location'):
        each_val['location'] = event.get('location')

    each_val['attendees'] = []
    attendees = event.get('attendee')

    if attendees:
        for each_attendee in attendees:
            each_val['attendees'].append(each_attendee)

    result_list.append(each_val)

# %%
result_list
# Out:
# [{'start': datetime.date(2007, 8, 7),
#   'end': datetime.date(2007, 8, 8),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2007, 11, 30, 23, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2007, 12, 1, 0, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2007, 11, 30, 15, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2007, 11, 30, 16, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2007, 12, 4, 20, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2007, 12, 4, 21, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2007, 12, 4, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2007, 12, 4, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2007, 12, 7, 1, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2007, 12, 7, 2, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2007, 12, 13, 22, 45, tzinfo=<UTC>),
#   'end': datetime.datetime(2007, 12, 13, 23, 45, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2007, 12, 5, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2007, 12, 5, 21, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 1, 31, 15, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 1, 31, 16, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'eye2eye''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 2, 4, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 2, 4, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 2, 9, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 2, 9, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 3, 5, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 3, 5, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 2, 28, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 2, 28, 2, 0, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'Cafe Fuego''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 2, 28, 13, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 2, 28, 16, 0, tzinfo=<UTC>),
#   'duration': 9000,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'Heller Ehrman LLP''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 3, 3, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 3, 3, 23, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Ashish Cell: 917-209-1623\\nDan Cell: 646-319-4115\\n================\\n\\nSounds good...we\'ll find someplace quite to talk.\\n\\n--DME\\n\\nOn Thu\\, Feb 28\\, 2008 at 11:46 AM\\, Ashish Singal  wrote:\\n> You\'re right .. tagging properly isn\'t easy.\\n>  \\n>  Monday around 5pm? We can find a coffeeshop near the 4/5 stop down here.\\n>  \\n>  \\n>  On Wed\\, Feb 27\\, 2008 at 9:19 PM\\, Daniel M. Eldridge\\n>  \\n> \\n>  wrote:\\n>  > Next Tue sounds good to me. I\'m hoping to go to the NYTech\\, but I am\\n>  >  not yet signed up for it and I have to wait for some slots to open up\\n>  >  @ 2pm on the day of the event\\, but I\'ll keep trying.\\n>  >\\n>  >  Monday\\, PM works for me too and is better for me. Anytime post 4:30\\n>  >  works for me--I can easily come d\'town as I\'ll be in Midtown on the\\n>  >  East side.\\n>  >\\n>  >  BTW\\, here\'s the googlified dmoz:\\n>  >    http://www.google.com/Top/\\n>  >\\n>  >  As for folksonomy...I\'ve heard the term and the concept before\\; I\'ve\\n>  >  always been confused about folksonomy--\'cause I don\'t see and\\n>  >  advantages...all I see are dis-advantages.\\n>  >\\n>  >  Maybe this is because I think tagging my own bookmarks is hard\\; maybe\\n>  >  this is because I know how hard it is to create an index for a\\n>  >  book--or a document\\; maybe this is because I know how hard it is to\\n>  >  keyword photos\\; maybe this is because I am over thinking this\\; maybe\\n>  >  this is because I wasn\'t very good @ google\'s image tagging game.\\n>  >  Maybe it\'s because I am more demanding and expect more than 10th grade\\n>  >  quality? Maybe it\'s because I am right and folksonomy is stupid.\\n>  >\\n>  >  --DME\\n>  >\\n>  >\\n>  >\\n>  >\\n>  >  On Wed\\, Feb 27\\, 2008 at 11:15 AM\\, Ashish Singal\\n>  >   wrote:\\n>  >  > I enjoyed our conversation very much as well. I had actually taken a\\n>  >  >  look at the folksonomy wikipedia page a while ago\\, but yes\\, we\\n>  >  >  concluded that there needs to be some sort of methodology to\\n>  >  >  effectively tag this stuff -- not just let anyone put in any tags.\\n>  >  >\\n>  >  >  Perhaps Monday or Tuesday of next week\\, we can get some coffee? I\'m\\n>  >  >  planning on going to the NY Tech meet up on Tuesday .. are you going?\\n>  >  >  We can meet before the meet up for a little while if that works for\\n>  >  >  you.\\n>  >  >\\n>  >  >\\n>  >  >\\n>  >  >  On Tue\\, Feb 26\\, 2008 at 7:06 PM\\, Daniel M. Eldridge\\n>  >  >   wrote:\\n>  >  >  > Ashish\\, it was a pleasure to speak with you and discuss web-espy and\\n>  >  >  >  my thinking on the topic. My data harvesting project was called\\n>  >  >  >  virgindata\\, but I think your webespy is much better. I had no idea\\n>  >  >  >  that espy was a word\\, much less than it "to discern" or "to\\n>  >  >  >  appreciate"\\n>  >  >  >  http://en.wiktionary.org/wiki/espy\\n>  >  >  >\\n>  >  >  >  I hope we can get together sometime in the next week or so to discuss\\n>  >  >  >  this and other topics. In the meantime here\'s more info on some of the\\n>  >  >  >  topics we discussed\\,\\n>  >  >  >\\n>  >  >  >  --Dan Eldridge\\n>  >  >  >\\n>  >  >  >\\n>  >  >  >  DIRECTORIES:\\n>  >  >  >\\n>  >  >  >  Looksmart was the directory I couldn\'t remember.\\n>  >  >  >  According to this article it\'s kaput:\\n>  >  >  >    http://en.wikipedia.org/wiki/List_of_web_directories\\n>  >  >  >\\n>  >  >  >  But that article lists several directories I did not know about.\\n>  >  >  >\\n>  >  >  >  I got to this page from the DMOZ.org entry:\\n>  >  >  >    http://en.wikipedia.org/wiki/Dmoz.org#See_also\\n>  >  >  >\\n>  >  >  >  Note the paragraph above the See Also Section:\\n>  >  >  >  Hierarchical structure\\n>  >  >  >  Recently criticism of ODP\'s hierarchical structure emerged. Many\\n>  >  >  >  believe hierarchical directories are too complicated. As the recent\\n>  >  >  >  emergence of Web 2.0\\, folksonomies began to ...
#   'location': vText('b'Starbucks @ Hanover Square''),
#   'attendees': [vCalAddress('b'mailto:deldridge@gmail.com''),
#    vCalAddress('b'mailto:ashish.singal1@gmail.com'')]},
#  {'start': datetime.datetime(2008, 3, 27, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 3, 27, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Dial-in Number:1-218-339-7800 \\n\\n\\n\\nParticipant Access Code: 68503''),
#   'attendees': [vCalAddress('b'mailto:adam@sparkker.com''),
#    vCalAddress('b'mailto:dan@sparkker.com''),
#    vCalAddress('b'mailto:ashish.singal1@gmail.com'')]},
#  {'start': datetime.datetime(2008, 5, 15, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 5, 15, 21, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2008, 5, 23, 13, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2008, 5, 23, 14, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2011, 7, 22),
#   'end': datetime.date(2011, 7, 24),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': [vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:reunion@northwestern.edu''),
#    vCalAddress('b'mailto:event-information@certain.com'')]},
#  {'start': datetime.datetime(2011, 10, 29, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2011, 10, 29, 6, 0, tzinfo=<UTC>),
#   'duration': 18000,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b"Copying some others\\, mason and I are in\\n\\nSent from my iPhone\\n\\nOn Oct 9\\, 2011\\, at 4:20 PM\\, Joe Rooney <rooney.joseph@gmail.com> wrote:\\n\\nI'm in\\, Dustin said its a really good time\\n\\nOn Oct 9\\, 2011\\, at 4:32 PM\\, David Cho <thedcho@gmail.com> wrote:\\n\\nI doubt any of you would be interested in this considering it will largely be NYU dental students\\; however\\, I thought I'd forward this to you anyway just in case. Let me know.\\n\\n---------- Forwarded message ----------\\nFrom: Shawn Motlagh <sm3419@nyu.edu>\\nDate: Sun\\,..."'),
#   'location': vText('b'Crimson NYC on Broadway and 21st.''),
#   'attendees': []},
#  {'start': datetime.datetime(2011, 10, 12, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2011, 10, 13, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Hello\\,\\n\\nThank you for expressing interest in the Kaplan SAT Prep program. With the help of dedicated volunteers like you\\, New York Cares will help 1\\,000 New York City high school students improve their SAT scores and their chances of getting into the college of their choice.\\n\\nYour combination New York Cares orientation and training session is scheduled for Wednesday\\, October 12 th at 7:00pm. The training will take place in the New York Cares orientation room on the 7 th floor of 214 West 29 th Street. To...''),
#   'attendees': []},
#  {'start': datetime.datetime(2012, 3, 25, 4, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2012, 3, 25, 10, 0, tzinfo=<UTC>),
#   'duration': 21600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Refune pres. Sebastian Ingrosso & Friends at Amnesia\\nAMNESIA MIAMI\\n136\\, Collins Avenue \\nMiami Beach\\, FL 33139 ''),
#   'attendees': [vCalAddress('b'mailto:keritter@gmail.com''),
#    vCalAddress('b'mailto:peter.bercovich@gmail.com''),
#    vCalAddress('b'mailto:masonpan@gmail.com''),
#    vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:rooney.joseph@gmail.com''),
#    vCalAddress('b'mailto:nickmccarty@gmail.com'')]},
#  {'start': datetime.datetime(2012, 4, 18, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2012, 4, 18, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': ['m',
#    'a',
#    'i',
#    'l',
#    't',
#    'o',
#    ':',
#    'a',
#    's',
#    'h',
#    'i',
#    's',
#    'h',
#    '.',
#    's',
#    'i',
#    'n',
#    'g',
#    'a',
#    'l',
#    '1',
#    '@',
#    'g',
#    'm',
#    'a',
#    'i',
#    'l',
#    '.',
#    'c',
#    'o',
#    'm']},
#  {'start': datetime.datetime(2012, 6, 24, 16, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2012, 6, 24, 17, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 2, 7, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 2, 8, 1, 0, tzinfo=<UTC>),
#   'duration': 9000,
#   'status': vText('b'TENTATIVE''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 1, 29, 23, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 1, 30, 0, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Tuesday\\, January 29\\, 2013\\nat 6:30 PM\\n\\nBrunswick Group Inc\\n135 East 57th Street\\nNew York\\, NY 10022\\n''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 1, 27, 2, 0, tzinfo=<UTC>),
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Reservations for 2013-01-26 21:00:00-05:00\\, party of 2.''),
#   'location': vText('b'22 W 8th St\\, New York\\, NY 10011''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 3, 23, 23, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 3, 24, 0, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 3, 29, 1, 15, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 3, 29, 3, 0, tzinfo=<UTC>),
#   'duration': 6300,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'DELTA 6109\\, seat 09C\\nFlight Confirmation #: G93T6I''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 3, 31, 23, 20, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 4, 1, 13, 1, tzinfo=<UTC>),
#   'duration': 49260,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Flight Confirmation #: G93T6I\\nDELTA 6110seat07C''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 3, 18, 19, 34, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 3, 19, 4, 3, tzinfo=<UTC>),
#   'duration': 30540,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Flight: UA980\\nseat 10D''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 4, 23, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 4, 24, 0, 30, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For details\\, link here: http://workdifferentlyny.eventbrite.com''),
#   'location': vText('b'WeWork Lounge - 154 Grand Street - New York\\, NY 10013''),
#   'attendees': []},
#  {'start': datetime.date(2013, 4, 21),
#   'end': datetime.date(2013, 4, 26),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 4, 21, 1, 45, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 4, 21, 2, 45, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 4, 21, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 4, 21, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 4, 27, 3, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 4, 27, 4, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 4, 28, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 4, 28, 2, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 4, 16, 18, 25, tzinfo=<UTC>),
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 13, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 13, 23, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 2, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 2, 22, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2013, 7, 26),
#   'end': datetime.date(2013, 7, 29),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2013, 8, 2),
#   'end': datetime.date(2013, 8, 6),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2013, 8, 9),
#   'end': datetime.date(2013, 8, 11),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2013, 8, 22),
#   'end': datetime.date(2013, 8, 26),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 4, 30, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 3, 1, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 10, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 11, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 3, 17, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 3, 18, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'birch coffee ''),
#   'attendees': []},
#  {'start': datetime.date(2013, 6, 1),
#   'end': datetime.date(2013, 6, 3),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 6, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 7, 0, 45, tzinfo=<UTC>),
#   'duration': 8100,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/Meteor-NY/events/113616192/\\nMeteor NY\\nWe&#039\\;ll have one or two brief video conference sessions (10 minutes each) covering the basics of Meteor. The rest of the time will be so&hellip\\;''),
#   'location': vText('b'10Gen - 229 W. 43rd St. 5th Floor - New York\\, NY 10036''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 7, 22, 15, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 8, 1, 15, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/nyccloudcomputing/events/113809052/\\nNew York City Cloud Computing Group\\nAWS\xc2\xa0Economics: Learn how to efficiently optimize your resource utilization and control your costs\\nJoin us for a presentation on how to buy only &hellip\\;''),
#   'location': vText('b'Gemini Systems LLC - 61 Broadway - New York\\, NY''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 16, 20, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 16, 21, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 15, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 15, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/Lean-Coffee-NYC/events/115924482/\\nLean Coffee NYC\\nWe&#039\\;re testing out an night time meetup for those who couldn&#039\\;t make it to the morning sessions.\\nFor this session\\, we&#039\\;ll s&hellip\\;''),
#   'location': vText('b'AlleyNYC - 500 7th ave 17th floor - New York\\, NY 10018''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 17, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 17, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 17, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 17, 23, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 18, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 18, 3, 0, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 6, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 8, 15, 30, tzinfo=<UTC>),
#   'duration': 63000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 23, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 23, 22, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 22, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 22, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 22, 19, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 22, 20, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 22, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 22, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 23, 10, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 23, 11, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 30, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 26, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 26, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 3, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 4, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 23, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/hatchery/events/116989062/\\nThe Hatchery - New York Dot Comers\\nInnovation... What&#039\\;s going on with social... and how to work with agencies.\\nSo you\xe2\x80\x99ve built your product\\, you\xe2\x80\x99ve raised your mon&hellip\\;''),
#   'location': vText('b'The Hatchery - 1601 Broadway (entrance on 48th St. northwest corner) 12th floor - New York\\, NY''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 28, 12, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 28, 15, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'UWS Startup Meetup\\nTuesday\\, May 28 at 8:30 AM\\n\\nCome meet us at the Upstairs Couches at Aroma Espresso Bar!\\n\\n\\n For more NY dining options with entrepreneurs\\, check out\\n\\n http://amusemi.com\\n\xc2\xa0\\n\\nDetails: http://www.meetup.com/UWS-Startup-Meetup/events/112622372/''),
#   'location': vText('b'Aroma Espresso Bar (161 W 72nd Street \\, New York\\, NY 10023)''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 5, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 6, 1, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'New York Startup Pitch Night\\nWednesday\\, June 5 at 6:30 PM\\n\\nAGENDA 6:30 - Networking.  7:10 - 10 minute introduction from the Organizers. 7:20 - 60 Second Pitches (approx. 30-40 people). 8:00 - Guest Speaker - ...\\n\\nFee: Price: USD 5.00 per person\\n\\nDetails: http://www.meetup.com/New-York-Startup-Pitch-Night/events/88291022/''),
#   'location': vText('b'INC39 (142 East 39th Street\\, New York\\, NY\\, New York\\, NY 10016)''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 28, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 28, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 29, 23, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 30, 1, 30, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Reservations for 2013-05-29 19:30:00-04:00\\, party of 2.''),
#   'location': vText('b'18 Cornelia St\\, New York\\, NY 10014''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 23, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 1, 0, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'frying pan''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 30, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 30, 14, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 2, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 2, 2, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 3, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 3, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 3, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 3, 22, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 30, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 30, 22, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 6, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 6, 22, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 30, 15, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 30, 15, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 30, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 30, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 14, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 6, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 7, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 17, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 15, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 16, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 5, 31, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 5, 31, 21, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 3, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 3, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 12, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 13, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 16, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 16, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2013, 6, 21),
#   'end': datetime.date(2013, 6, 26),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 5, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 5, 2, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 5, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 5, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 11, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 11, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 10, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 10, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 6, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 6, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 10, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 10, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 7, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 7, 14, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 7, 14, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 7, 15, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 7, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 7, 17, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 11, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 11, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 12, 14, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 12, 15, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 13, 18, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 13, 19, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 17, 21, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 17, 22, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 27, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 27, 2, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 19, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 20, 1, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 18, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 18, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 20, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 20, 23, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 18, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 18, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 20, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 20, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 28, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 28, 23, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/hatchery/events/122671952/\\n\\nThe Hatchery - New York Dot Comers\\n\\nCome meet investors representing a NY angel network looking for great companies to invest in.\\n\\nLong Island Angel Network is a technology-&hellip\\;''),
#   'location': vText('b'The Hatchery - 1601 Broadway (entrance on 48th St. northwest corner) 12th floor - New York\\, NY''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 26, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 27, 2, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For details\\, link here: http://www.eventbrite.com/event/6929549469''),
#   'location': vText('b'500 7th ave - 17th floor - New York\\, 10018''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 6, 27, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 6, 28, 1, 0, tzinfo=<UTC>),
#   'duration': 9000,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/hackshackersny/events/122016242/\\nHacks/Hackers New York\\nHacks/Hackers NYC is pleased to announce The Summer 2013 Demo Day presentations:\\n\xe2\x80\xa2 Johnny Dwyer\\, R/GA - &#034\\;Words &amp\\; Votes&#&hellip\\;''),
#   'location': vText('b'Pivotal Labs - 841 Broadway\\, 8th floor - New York\\, NY 10003''),
#   'attendees': []},
#  {'start': datetime.date(2013, 10, 26),
#   'end': datetime.date(2013, 10, 27),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 12, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 12, 23, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/hatchery/events/122671952/\\nThe Hatchery - New York Dot Comers\\nCome meet investors representing a NY angel network looking for great companies to invest in.\\n\\nLong Island Angel Network is a technology- and innovat&hellip\\;''),
#   'location': vText('b'The Hatchery - 1601 Broadway (entrance on 48th St. northwest corner) 12th floor - New York\\, NY''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 2, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 2, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 8, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 12, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 10, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 11, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 1, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 1, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2013, 7, 20),
#   'end': datetime.date(2013, 7, 22),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 2, 16, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 2, 17, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 2, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 2, 21, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 18, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 18, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 19, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 16, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 17, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 21, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 19, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 17, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 18, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 17, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 19, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 20, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': ['m',
#    'a',
#    'i',
#    'l',
#    't',
#    'o',
#    ':',
#    'm',
#    'i',
#    's',
#    's',
#    'm',
#    'y',
#    'e',
#    'e',
#    '@',
#    'g',
#    'm',
#    'a',
#    'i',
#    'l',
#    '.',
#    'c',
#    'o',
#    'm']},
#  {'start': datetime.datetime(2013, 7, 11, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 12, 1, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 20, 15, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 21, 0, tzinfo=<UTC>),
#   'duration': 2700,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 3, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 3, 20, 15, tzinfo=<UTC>),
#   'duration': 900,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 9, 1, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 9, 2, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 10, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 10, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 9, 15, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 9, 16, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 10, 16, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 10, 17, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 9, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 9, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 9, 16, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 9, 17, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 10, 15, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 10, 16, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 11, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 11, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 12, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 12, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 10, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 10, 22, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 15, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 16, 0, 0, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For details\\, link here: http://www.eventbrite.com/event/7347002081''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 11, 21, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 11, 22, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 12, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 12, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 17, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 17, 23, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 15, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 15, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 15, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 15, 21, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 12, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 12, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 16, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 16, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 17, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 17, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 15, 13, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 15, 13, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 15, 13, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 15, 14, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 15, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 15, 14, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 15, 14, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 15, 15, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.date(2013, 9, 18),
#   'end': datetime.date(2013, 9, 23),
#   'duration': 0,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 22, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 22, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 19, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 19, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': [vCalAddress('b'mailto:peter.bercovich@gmail.com''),
#    vCalAddress('b'mailto:ashish.singal1@gmail.com'')]},
#  {'start': datetime.datetime(2013, 7, 22, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 22, 23, 20, tzinfo=<UTC>),
#   'duration': 3000,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b"Pete's Tavern on 18th and Irving"'),
#   'attendees': [vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:ksowocki@gmail.com'')]},
#  {'start': datetime.datetime(2013, 7, 30, 12, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 30, 15, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/UWS-Startup-Meetup/events/125124622/\\n\\nUWS Startup Meetup\\n\\nCome meet us at the Upstairs Couches at Aroma Espresso Bar!\\n\\nFor more NY dining options with entrepreneurs\\, check out\\n\\nhttp://am&hellip\\;''),
#   'location': vText('b'Aroma Espresso Bar - 161 W 72nd Street - New York\\, NY 10023''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 7, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 8, 1, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/New-York-Startup-Pitch-Night/events/128764462/\\n\\nNew York Startup Pitch Night\\n\\nAre you joining us on August 7th in New York City?\\n\\nTo practice your 60-second elevator pitch\\,\\nReceive anonymous scoring feedback from&hellip\\;''),
#   'location': vText('b'- \\,''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 24, 16, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 24, 17, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 24, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 24, 19, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 3, 14, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 3, 17, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/NYC-Startup-and-Dim-Sum-Enthusiasts/events/124340212/\\n\\nNYC Startup and Dim Sum Enthusiasts''),
#   'location': vText('b'Jing Fong Restaurant - 20 Elizabeth St - New York\\, NY 10013''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 25, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 25, 21, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 26, 0, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 26, 6, 0, tzinfo=<UTC>),
#   'duration': 19800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'For full details\\, including the address\\, and to RSVP see:\\nhttp://www.meetup.com/StartupMonthlyNYC/events/120767052/\\n\\nStartupMonthly New York\\n\\nStartup Socials Party NY July 2013\\nNote: This event is 21+\\nMUST RSVP on EventBrite to attend the event\xc2\xa0http://socialsnyjuly2013.eve&hellip\\;''),
#   'location': vText('b'Soaked Soho - 150 Lafayette St - 10013\\, NY 10013''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 7, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 8, 2, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 2, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 2, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 31, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 31, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 5, 16, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 5, 17, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Mike to call Ashish''),
#   'location': vText('b'desk''),
#   'attendees': [vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:mbreslin16@gmail.com'')]},
#  {'start': datetime.datetime(2013, 7, 31, 23, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 1, 0, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 30, 18, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 30, 19, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 7, 31, 16, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 7, 31, 18, 0, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'meatpacking''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 1, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2013, 8, 1, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'tomokos''),
#   'attendees': []},
#  {'start': datetime.datetime(2013, 8, 18, 0, 0, tzinfo=<UTC>),
# ...
#   'duration': 18000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 25, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 25, 4, 0, tzinfo=<UTC>),
#   'duration': 14400,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 25, 4, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 25, 7, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 25, 7, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 25, 10, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 25, 10, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 25, 14, 0, tzinfo=<UTC>),
#   'duration': 14400,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 25, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 25, 20, 0, tzinfo=<UTC>),
#   'duration': 21600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 25, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 26, 2, 0, tzinfo=<UTC>),
#   'duration': 21600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 26, 2, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 26, 5, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 26, 5, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 26, 8, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 26, 8, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 26, 11, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 26, 11, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 26, 19, 0, tzinfo=<UTC>),
#   'duration': 28800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 26, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 27, 5, 0, tzinfo=<UTC>),
#   'duration': 36000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 27, 5, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 27, 7, 0, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 27, 7, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 27, 11, 0, tzinfo=<UTC>),
#   'duration': 14400,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 27, 11, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 27, 14, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 27, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 27, 22, 0, tzinfo=<UTC>),
#   'duration': 28800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 27, 23, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 28, 21, 0, tzinfo=<UTC>),
#   'duration': 77400,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 28, 21, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 2, 0, tzinfo=<UTC>),
#   'duration': 16200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 31, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 31, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': [vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:adamgassman.newsmakeup@gmail.com'')]},
#  {'start': datetime.datetime(2014, 1, 31, 0, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 31, 1, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 2, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 5, 30, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 6, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 9, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 13, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 14, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 9, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 13, 30, tzinfo=<UTC>),
#   'duration': 16200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 3, 14, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 3, 15, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 21, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 22, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 31, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 31, 23, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 23, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 20, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 21, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 21, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 22, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 14, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 29, 19, 0, tzinfo=<UTC>),
#   'duration': 16200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 29, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 0, 30, tzinfo=<UTC>),
#   'duration': 19800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 20, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 21, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 19, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 20, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 0, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 4, 30, tzinfo=<UTC>),
#   'duration': 14400,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 9, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 10, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 10, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 11, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 30, 11, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 30, 12, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 31, 3, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 31, 10, 0, tzinfo=<UTC>),
#   'duration': 25200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 31, 11, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 31, 12, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 31, 12, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 31, 12, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 1, 31, 13, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 1, 31, 21, 30, tzinfo=<UTC>),
#   'duration': 30600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 1, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 3, 30, tzinfo=<UTC>),
#   'duration': 9000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 3, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 10, 30, tzinfo=<UTC>),
#   'duration': 25200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 11, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 12, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 12, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 12, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 15, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 16, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 13, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 15, 30, tzinfo=<UTC>),
#   'duration': 9000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 17, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 18, 0, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 18, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 1, 22, 0, tzinfo=<UTC>),
#   'duration': 14400,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 1, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 2, 8, 30, tzinfo=<UTC>),
#   'duration': 36000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 2, 9, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 2, 10, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 2, 10, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 2, 10, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 4, 17, 5, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 4, 18, 5, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Attendee: Adam Gassman (adamgassman.newsmakeup@gmail.com)\\nSubject: weekly meeting\\nMeeting Room: Board Room\\nLocation: Board Room\\n\\nCancel/Reschedule link: http://app.scheduleonce.com/AlleyRooms&update=MTE1NTIyOAqualqual\\n''),
#   'location': vText('b'Board Room''),
#   'attendees': [vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:adamgassman.newsmakeup@gmail.com'')]},
#  {'start': datetime.datetime(2014, 2, 2, 11, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 2, 17, 0, tzinfo=<UTC>),
#   'duration': 19800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 2, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 2, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 2, 18, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 2, 22, 0, tzinfo=<UTC>),
#   'duration': 12600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 2, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 2, 23, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 3, 0, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 3, 2, 30, tzinfo=<UTC>),
#   'duration': 9000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 3, 3, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 3, 10, 30, tzinfo=<UTC>),
#   'duration': 27000,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 5, 2, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 5, 3, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 5, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 5, 17, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'\\n\\n''),
#   'location': vText('b'skype''),
#   'attendees': ['m',
#    'a',
#    'i',
#    'l',
#    't',
#    'o',
#    ':',
#    'a',
#    's',
#    'h',
#    'i',
#    's',
#    'h',
#    '.',
#    's',
#    'i',
#    'n',
#    'g',
#    'a',
#    'l',
#    '1',
#    '@',
#    'g',
#    'm',
#    'a',
#    'i',
#    'l',
#    '.',
#    'c',
#    'o',
#    'm']},
#  {'start': datetime.datetime(2014, 2, 3, 11, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 3, 12, 30, tzinfo=<UTC>),
#   'duration': 5400,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 3, 12, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 3, 13, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 4, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 4, 21, 30, tzinfo=<UTC>),
#   'duration': 1800,
#   'status': vText('b'CONFIRMED''),
#   'location': vText('b'Phone''),
#   'attendees': [vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:perryr@seosherpas.com''),
#    vCalAddress('b'mailto:adamgassman.newsmakeup@gmail.com'')]},
#  {'start': datetime.datetime(2014, 2, 3, 16, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 3, 22, 0, tzinfo=<UTC>),
#   'duration': 19800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 4, 16, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 4, 17, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'description': vText('b'Web Espy biz dev.''),
#   'location': vText('b'500 Seventh Ave\\, Fl 17''),
#   'attendees': [vCalAddress('b'mailto:ashish.singal1@gmail.com''),
#    vCalAddress('b'mailto:iviahuja@gmail.com'')]},
#  {'start': datetime.datetime(2014, 2, 3, 22, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 4, 1, 0, tzinfo=<UTC>),
#   'duration': 10800,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 4, 1, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 4, 3, 0, tzinfo=<UTC>),
#   'duration': 7200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 4, 3, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 4, 10, 0, tzinfo=<UTC>),
#   'duration': 25200,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 11, 17, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 11, 18, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 6, 21, 0, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 6, 22, 0, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  {'start': datetime.datetime(2014, 2, 5, 22, 30, tzinfo=<UTC>),
#   'end': datetime.datetime(2014, 2, 5, 23, 30, tzinfo=<UTC>),
#   'duration': 3600,
#   'status': vText('b'CONFIRMED''),
#   'attendees': []},
#  ...]
